# %%
# !pip3 install numpy
# !pip3 install scikit-fuzzy
# !pip3 install matplotlib
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

quality = ctrl.Antecedent(np.arange(0, 11, 1), 'quality')
service = ctrl.Antecedent(np.arange(0, 11, 1), 'service')
tip = ctrl.Consequent(np.arange(0, 26, 1), 'tip')

quality.automf(3)
service.automf(3)

tip['low'] = fuzz.trimf(tip.universe, [0, 0, 13])
tip['medium'] = fuzz.trimf(tip.universe, [0, 13, 25])
tip['high'] = fuzz.trimf(tip.universe, [13, 25, 25])

#quality.view()
#service.view()
#tip.view()

rule1 = ctrl.Rule(quality['poor'] & service['poor'], tip['low'])
rule2 = ctrl.Rule(service['average'], tip['medium'])
rule3 = ctrl.Rule(service['good'] | quality['good'], tip['high'])

tipping_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
tipping = ctrl.ControlSystemSimulation(tipping_ctrl)

tipping.input['quality'] = 6.5
tipping.input['service'] = 9.8

tipping.compute()

print(tipping.output['tip'])

tip.view(sim=tipping)
# Out:
# Requirement already satisfied: numpy in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (1.24.2)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-fuzzy in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from scikit-fuzzy) (1.24.2)
# Requirement already satisfied: scipy>=0.9.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from scikit-fuzzy) (1.10.1)
# Requirement already satisfied: networkx>=1.9.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from scikit-fuzzy) (3.0)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# 19.847607361963192
# /Users/derickmuli/.pyenv/versions/3.10-dev/lib/python3.10/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
